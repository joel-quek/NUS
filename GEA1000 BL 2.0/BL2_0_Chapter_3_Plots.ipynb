# %%
x=seq(4,8,length=100)

y=sin(x) #: modify a little with diff functions

e=rnorm(100,0,1) #: to create some variability
y=y+e

plot(x,y)
# Out:
# plot without title

# %%
x=seq(1,10,length=100)

y=sin(x) #: modify a little with diff functions

e=rnorm(100,0,0.1) #: to create some variability
y=y+e

plot(x,y)
# Out:
# plot without title

# %%
x=seq(-5,5,length=100)

y=x^2 #: modify a little with diff functions

e=rnorm(100,0,2) #: to create some variability
y=y+e

plot(x,y)
# Out:
# plot without title

# %%
x=seq(-2,8,length=100)

y=log(x, base = exp(1)) #: modify a little with diff functions

e=rnorm(100,0,0.1) #: to create some variability
y=y+e

plot(x,y)
# Out:
# Warning message in eval(expr, envir, enclos):
# “NaNs produced”
# plot without title

# %%
x = seq(4, 8, length = 100)

# Generate y values with correlation coefficient of 0.9
correlation = 0.98
y = correlation * x  # Modify the relationship between x and y
e = rnorm(100, 0, 1)
y = y + e

plot(x, y)
# Out:
# plot without title

# %%
x=seq(4,8,length=100)

y=-x #: modify a little with diff functions

e=rnorm(100,0,0.2) #: to create some variability
y=y+e

plot(x,y)
# Out:
# plot without title

# %%
cor(x,y)
# Out:
# [1] -0.9898917

# %%
x <- seq(4, 8, length = 100)

# Introduce an outlier in y
y <- -x
e <- rnorm(100, 0, 0.2)
y <- y + e

# Introduce an outlier by modifying one data point
outlier_index <- 50  # Index of the data point to be modified
y[outlier_index] <- 10  # Set the outlier value

plot(x, y, pch=16, col="black")
# Out:
# plot without title

# %%
x <- seq(4, 8, length = 100)

# Create a linear relationship between x and y
y <- -x
e <- rnorm(100, 0, 0.2)
y <- y + e

# Create an outlier that falls on the regression line
outlier_index <- 50  # Index of the data point to be modified
y[outlier_index] <- -x[outlier_index]  # Set the outlier value on the regression line

plot(x, y)
# Out:
# plot without title

# %%
x <- seq(4, 8, length = 100)

# Create a linear relationship between x and y
y <- -x
e <- rnorm(100, 0, 0.2)
y <- y + e

# Filter out points between 6 and 7.9
filter_indices <- x < 6 | x > 7.9
x_filtered <- x[filter_indices]
y_filtered <- y[filter_indices]

plot(x_filtered, y_filtered, pch=16, col="black")
# Out:
# plot without title

# %%
x <- seq(4, 8, length = 100)

# Create a linear relationship between x and y
y <- -x
e <- rnorm(100, 0, 0.2)
y <- y + e

# Set index and color for the outlier
outlier_index <- 50  # Index of the outlier point
outlier_color <- "red"  # Color for the outlier point

# Create vector for point colors
point_colors <- ifelse(1:length(x) == outlier_index, outlier_color, "black")

plot(x, y, pch = 16, col = point_colors, bg = point_colors)
# Out:
# plot without title

# %%
library(ggplot2)

# Generate data for clustered points
theta <- seq(0, 2*pi, length.out = 100)
radius <- 1
x_clustered <- radius * cos(theta)
y_clustered <- radius * sin(theta)

# Generate data for outlier point
x_outlier <- 4
y_outlier <- 4

# Create data frame
data <- data.frame(x = c(x_clustered, x_outlier),
                   y = c(y_clustered, y_outlier),
                   group = c(rep("Clustered", length(x_clustered)), "Outlier"))

# Create scatter plot
ggplot(data, aes(x, y, color = group)) +
  geom_point() +
  theme_bw()
# Out:
# plot without title

# %%
library(ggplot2)

# Generate data for clustered points
n_clustered <- 100
x_clustered <- rnorm(n_clustered, mean = 2, sd = 0.5)
y_clustered <- rnorm(n_clustered, mean = 2, sd = 0.5)

# Generate data for outlier point
x_outlier <- 10
y_outlier <- 10

# Create data frame
data <- data.frame(x = c(x_clustered, x_outlier),
                   y = c(y_clustered, y_outlier),
                   group = c(rep("Clustered", n_clustered), "Outlier"))

# Create scatter plot
ggplot(data, aes(x, y, color = group)) +
  geom_point() +
  theme_bw()
# Out:
# plot without title

# %% [markdown]
# ---

# %% [markdown]
# #OPENINTROSTAT.GITHUB.IO

# %% [markdown]
# A quick note on how you may export data sets embedded in R package.
#
#
#
# The text "Introduction to Modern Statistics" https://openintro-ims.netlify.app/index.html has some data sets packaged together in the R package openintro
#
#
#
# For example, to get the data for Q8 of Section 3.2.7
#
# https://openintro-ims.netlify.app/intro-linear-models.html#least-squares-regression-exercises
#
# If you click on the footnote labelled as 88, you will see the following text "The data used in this exercise can be found in the openintro package: bdims"
#
#
#
# On R do the following
#
#
#
# if (!require('openintro')) install.packages('openintro')
# library('openintro')
# write.csv(bdims, file="bdmis.csv", row.names = F)
# getwd()
#
#
# (1) will install the openintro package on R, if you do not have it already
#
# (2) will load the package
#
# (3) will export the data set bdims (in this case) and write it to a csv file to the current working directory
#
# (4) lets you know where your current working directory is
#
#
#
# By the way, I was telling Amanda about the penguin data set that you can consider using.
# https://allisonhorst.github.io/palmerpenguins/
#
#
#
# You can export and grab the data set in the same manner,

# %%
if (!require('openintro')) install.packages('openintro')

library('openintro')

write.csv(bdims, file="bdmis.csv", row.names = F)

getwd()

# %% [markdown]
# ## SOURCE 1
#
# http://openintrostat.github.io/openintro/reference/elmhurst

# %%
library(ggplot2)
library(broom)

ggplot(elmhurst, aes(x = family_income, y = gift_aid)) +
  geom_point() +
  geom_smooth(method = "lm")+
  labs(x = "Family Income", y = "Financial Aid")
#> `geom_smooth()` using formula = 'y ~ x'
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
correlation <- cor(elmhurst$family_income, elmhurst$gift_aid)
correlation
# Out:
# [1] -0.4985561

# %% [markdown]
# # SOURCE 2

# %%
library(ggplot2)
library(dplyr)

# %%
# Course grade vs. each exam
ggplot(exam_grades, aes(x = exam1, y = course_grade)) +
  geom_point()
#> Warning: Removed 1 rows containing missing values (`geom_point()`).
# Out:
# Warning message:
# “Removed 1 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggplot(exam_grades, aes(x = exam2, y = course_grade)) +
  geom_point() +
  labs(x = "Midterm Grade", y = "Final Grade")
# Out:
# plot without title

# %%
correlation <- cor(exam_grades$exam2, exam_grades$course_grade)
correlation
# Out:
# [1] 0.7473812

# %% [markdown]
# ---

# %% [markdown]
# $SU_X = \frac{X - average(X)}{s_x}$ &#8195;   $SU_Y = \frac{Y - average(Y)}{s_y}$

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate four distinct clusters with collinear data
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 1)
y1 <- x1 + rnorm(n, mean = 0, sd = 0.5)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 1)
y2 <- x2 + rnorm(n, mean = 0, sd = 0.5)

# Cluster 3
x3 <- rnorm(n, mean = 8, sd = 1)
y3 <- x3 + rnorm(n, mean = 0, sd = 0.5)

# Cluster 4
x4 <- rnorm(n, mean = 12, sd = 1)
y4 <- x4 + rnorm(n, mean = 0, sd = 0.5)

# Combine the data
data <- data.frame(x = c(x1, x2, x3, x4),
                   y = c(y1, y2, y3, y4),
                   cluster = rep(1:4, each = n))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate four smaller distinct clusters with rotated positions
n <- 100 # Number of data points per cluster

# Cluster 1 (Rotated)
y1 <- rnorm(n, mean = 0, sd = 0.5)
x1 <- -y1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2 (Rotated)
y2 <- rnorm(n, mean = 4, sd = 0.5)
x2 <- y2 + rnorm(n, mean = 0, sd = 0.2)

cluster_center <- data.frame(x = mean(x2), y = mean(y2))

rotated_x2 <- cluster_center$x + (y2 - cluster_center$y)
rotated_y2 <- cluster_center$y - (x2 - cluster_center$x)

# Cluster 3 (Rotated)
y3 <- rnorm(n, mean = 8, sd = 0.5)
x3 <- y3 + rnorm(n, mean = 0, sd = 0.2)

cluster_center <- data.frame(x = mean(x3), y = mean(y3))

rotated_x3 <- cluster_center$x + (y3 - cluster_center$y)
rotated_y3 <- cluster_center$y - (x3 - cluster_center$x)

# Cluster 4 (Rotated)
y4 <- rnorm(n, mean = 12, sd = 0.5)
x4 <- y4 + rnorm(n, mean = 0, sd = 0.2)

cluster_center <- data.frame(x = mean(x4), y = mean(y4))

rotated_x4 <- cluster_center$x + (y4 - cluster_center$y)
rotated_y4 <- cluster_center$y - (x4 - cluster_center$x)

# Combine the data
data <- data.frame(x = c(x1, rotated_x2, rotated_x3, rotated_x4),
                   y = c(y1, rotated_y2, rotated_y3, rotated_y4),
                   cluster = rep(1:4, each = n))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate four smaller distinct clusters with rotated positions
n <- 100 # Number of data points per cluster

# Cluster 1 (Rotated)
y1 <- rnorm(n, mean = 0, sd = 0.5)
x1 <- -y1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2 (Rotated)
y2 <- rnorm(n, mean = 4, sd = 0.5)
x2 <- y2 + rnorm(n, mean = 0, sd = 0.2)

cluster_center2 <- data.frame(x = mean(x2), y = mean(y2))

rotated_x2 <- cluster_center2$x + (y2 - cluster_center2$y)
rotated_y2 <- cluster_center2$y - (x2 - cluster_center2$x)

# Cluster 3 (Rotated)
y3 <- rnorm(n, mean = 8, sd = 0.5)
x3 <- y3 + rnorm(n, mean = 0, sd = 0.2)

cluster_center3 <- data.frame(x = mean(x3), y = mean(y3))

rotated_x3 <- cluster_center3$x + (y3 - cluster_center3$y)
rotated_y3 <- cluster_center3$y - (x3 - cluster_center3$x)

# Cluster 4 (Rotated)
y4 <- rnorm(n, mean = 12, sd = 0.5)
x4 <- y4 + rnorm(n, mean = 0, sd = 0.2)

cluster_center4 <- data.frame(x = mean(x4), y = mean(y4))

rotated_x4 <- cluster_center4$x + (y4 - cluster_center4$y)
rotated_y4 <- cluster_center4$y - (x4 - cluster_center4$x)

# Combine the data
data <- data.frame(x = c(x1, rotated_x2, rotated_x3, rotated_x4),
                   y = c(y1, rotated_y2, rotated_y3, rotated_y4),
                   cluster = rep(1:4, each = n))

# Create the scatter plot with cluster centers
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  geom_point(data = cluster_center2, aes(x = x, y = y), shape = 19, size = 4, color = "red", fill = "red") +
  geom_point(data = cluster_center3, aes(x = x, y = y), shape = 19, size = 4, color = "blue", fill = "blue") +
  geom_point(data = cluster_center4, aes(x = x, y = y), shape = 19, size = 4, color = "green", fill = "green") +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate three clusters with one cluster rotated by 90 degrees
n <- 100 # Number of data points per cluster

# Cluster 1 (Rotated)
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- -x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- x2 - rnorm(n, mean = 0, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 8, sd = 0.5)
y3 <- x3 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3),
                   y = c(y1, y2, y3),
                   cluster = rep(1:3, each = n))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate three clusters with each cluster rotated
n <- 100 # Number of data points per cluster

# Cluster 1 (Rotated)
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- -x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2 (Rotated)
angle2 <- 45 # Rotation angle for Cluster 2 (in degrees)
theta2 <- angle2 * pi / 180
rotation_matrix2 <- matrix(c(cos(theta2), -sin(theta2), sin(theta2), cos(theta2)), ncol = 2)
cluster2 <- matrix(c(rnorm(n, mean = 4, sd = 0.5), rnorm(n, mean = 0, sd = 0.2)), ncol = 2)
rotated_cluster2 <- cluster2 %*% rotation_matrix2
x2 <- rotated_cluster2[, 1]
y2 <- rotated_cluster2[, 2]

# Cluster 3 (Rotated)
angle3 <- -30 # Rotation angle for Cluster 3 (in degrees)
theta3 <- angle3 * pi / 180
rotation_matrix3 <- matrix(c(cos(theta3), -sin(theta3), sin(theta3), cos(theta3)), ncol = 2)
cluster3 <- matrix(c(rnorm(n, mean = 8, sd = 0.5), rnorm(n, mean = 0, sd = 0.2)), ncol = 2)
rotated_cluster3 <- cluster3 %*% rotation_matrix3
x3 <- rotated_cluster3[, 1]
y3 <- rotated_cluster3[, 2]

# Combine the data
data <- data.frame(x = c(x1, x2, x3),
                   y = c(y1, y2, y3),
                   cluster = rep(1:3, each = n))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate three clusters with each cluster rotated
n <- 100 # Number of data points per cluster

# Cluster 1 (Rotated)
angle1 <- 0 # Rotation angle for Cluster 1 (in degrees)
theta1 <- angle1 * pi / 180
rotation_matrix1 <- matrix(c(cos(theta1), -sin(theta1), sin(theta1), cos(theta1)), ncol = 2)
cluster1 <- matrix(c(rnorm(n, mean = 0, sd = 0.5), rnorm(n, mean = 0, sd = 0.2)), ncol = 2)
rotated_cluster1 <- cluster1 %*% rotation_matrix1
x1 <- rotated_cluster1[, 1]
y1 <- rotated_cluster1[, 2]

# Cluster 2 (Rotated)
angle2 <- 45 # Rotation angle for Cluster 2 (in degrees)
theta2 <- angle2 * pi / 180
rotation_matrix2 <- matrix(c(cos(theta2), -sin(theta2), sin(theta2), cos(theta2)), ncol = 2)
cluster2 <- matrix(c(rnorm(n, mean = 4, sd = 0.5), rnorm(n, mean = 0, sd = 0.2)), ncol = 2)
rotated_cluster2 <- cluster2 %*% rotation_matrix2
x2 <- rotated_cluster2[, 1]
y2 <- rotated_cluster2[, 2]

# Cluster 3 (Rotated)
angle3 <- -30 # Rotation angle for Cluster 3 (in degrees)
theta3 <- angle3 * pi / 180
rotation_matrix3 <- matrix(c(cos(theta3), -sin(theta3), sin(theta3), cos(theta3)), ncol = 2)
cluster3 <- matrix(c(rnorm(n, mean = 8, sd = 0.5), rnorm(n, mean = 0, sd = 0.2)), ncol = 2)
rotated_cluster3 <- cluster3 %*% rotation_matrix3
x3 <- rotated_cluster3[, 1]
y3 <- rotated_cluster3[, 2]

# Combine the data
data <- data.frame(x = c(x1, x2, x3),
                   y = c(y1, y2, y3),
                   cluster = rep(1:3, each = n))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate four distinct clusters with gaps
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- x2 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 8, sd = 0.5)
y3 <- x3 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 4
x4 <- rnorm(n, mean = 12, sd = 0.5)
y4 <- x4 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3, x4),
                   y = c(y1, y2, y3, y4),
                   cluster = rep(1:4, each = n))

# Create the scatter plot
scatter_plot <- ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()

# Add overall regression line
scatter_plot <- scatter_plot + geom_smooth(method = "lm", se = FALSE, color = "black")

# Add orthogonal regression lines for each cluster
scatter_plot <- scatter_plot + geom_smooth(data = data[data$cluster == 1, ],
                                           method = "lm",
                                           formula = y ~ -x,
                                           se = FALSE,
                                           color = "red") +
  geom_smooth(data = data[data$cluster == 2, ],
              method = "lm",
              formula = y ~ -x,
              se = FALSE,
              color = "blue") +
  geom_smooth(data = data[data$cluster == 3, ],
              method = "lm",
              formula = y ~ -x,
              se = FALSE,
              color = "green") +
  geom_smooth(data = data[data$cluster == 4, ],
              method = "lm",
              formula = y ~ -x,
              se = FALSE,
              color = "purple")

# Display the plot
scatter_plot
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate four distinct clusters with gaps
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- -x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- -x2 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 8, sd = 0.5)
y3 <- -x3 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 4
x4 <- rnorm(n, mean = 12, sd = 0.5)
y4 <- -x4 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3, x4),
                   y = c(y1, y2, y3, y4),
                   cluster = rep(1:4, each = n))

# Create the scatter plot
scatter_plot <- ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()

# Add overall regression line
scatter_plot <- scatter_plot + geom_smooth(method = "lm", se = FALSE, color = "black")

# Add orthogonal regression lines for each cluster
scatter_plot <- scatter_plot + geom_smooth(data = data[data$cluster == 1, ],
                                           method = "lm",
                                           formula = y ~ x,
                                           se = FALSE,
                                           color = "red") +
  geom_smooth(data = data[data$cluster == 2, ],
              method = "lm",
              formula = y ~ x,
              se = FALSE,
              color = "blue") +
  geom_smooth(data = data[data$cluster == 3, ],
              method = "lm",
              formula = y ~ x,
              se = FALSE,
              color = "green") +
  geom_smooth(data = data[data$cluster == 4, ],
              method = "lm",
              formula = y ~ x,
              se = FALSE,
              color = "purple")

# Display the plot
scatter_plot
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate three parallel and collinear clusters
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- x2 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 8, sd = 0.5)
y3 <- x3 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3),
                   y = c(y1, y2, y3),
                   cluster = rep(1:3, each = n))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate three parallel clusters with orthogonal orientations
n <- 100 # Number of data points per cluster

# Collinear line
x_collinear <- seq(-4, 12, length.out = n)
y_collinear <- x_collinear + rnorm(n, mean = 0, sd = 0.2)

# Cluster 1 (Orthogonal to collinear line)
x1 <- rnorm(n, mean = -2, sd = 0.5)
y1 <- -x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2 (Orthogonal to collinear line)
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- -x2 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 3 (Orthogonal to collinear line)
x3 <- rnorm(n, mean = 10, sd = 0.5)
y3 <- -x3 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data1 <- data.frame(x = x1, y = y1, cluster = rep(1, n), collinear = rep("Cluster 1", n))
data2 <- data.frame(x = x2, y = y2, cluster = rep(2, n), collinear = rep("Cluster 2", n))
data3 <- data.frame(x = x3, y = y3, cluster = rep(3, n), collinear = rep("Cluster 3", n))
data_collinear <- data.frame(x = x_collinear, y = y_collinear, cluster = rep(4, n), collinear = rep("Collinear", n))

data <- rbind(data1, data2, data3, data_collinear)

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster), shape = collinear)) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster", shape = "Orientation") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate two distinct clusters
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- x1 + rnorm(n, mean = 0, sd = 0.2)

cluster_center <- data.frame(x = mean(x1), y = mean(y1))
angle <- 0 * pi / 180
rotated_x1 <- (x1 - cluster_center$x) * cos(angle) - (y1 - cluster_center$y) * sin(angle)
rotated_y1 <- (x1 - cluster_center$x) * sin(angle) + (y1 - cluster_center$y) * cos(angle)

# Make the cluster wider
rotated_x1 <- rotated_x1 * 2.5

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- x2 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(rotated_x1, x2),
                   y = c(rotated_y1, y2),
                   cluster = rep(1:2, each = n))

# Fit the overall regression line
regression <- lm(y ~ x, data = data)

# Create the scatter plot with regression line
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  geom_abline(intercept = regression$coefficients[1],
              slope = regression$coefficients[2],
              linetype = "dashed",
              color = "black") +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate two distinct clusters
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- x2 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2),
                   y = c(y1, y2),
                   cluster = rep(1:2, each = n))

# Calculate cluster centers
cluster_centers <- aggregate(cbind(x, y) ~ cluster, data = data, FUN = mean)

# Fit the overall regression line
regression <- lm(y ~ x, data = data)

# Create the scatter plot with regression line
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point(size = 2) +
  geom_point(data = cluster_centers, aes(x = x, y = y), size = 4, shape = 21, fill = "black", color = "white") +
  geom_abline(intercept = regression$coefficients[1],
              slope = regression$coefficients[2],
              linetype = "dashed",
              color = "black") +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate three distinct clusters with positive correlations
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- x2 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 8, sd = 0.5)
y3 <- x3 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3),
                   y = c(y1, y2, y3),
                   cluster = rep(1:3, each = n))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate three distinct clusters with positive correlations within each cluster
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 3, sd = 0.5)
y2 <- x2 + rnorm(n, mean = 2, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 1.5, sd = 0.5)
y3 <- x3 + rnorm(n, mean = 4, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3),
                   y = c(y1, y2, y3),
                   cluster = rep(1:3, each = n))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate three distinct clusters with positive correlations within each cluster
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 3, sd = 0.5)
y2 <- x2 + rnorm(n, mean = 2, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 0.4, sd = 0.5)
y3 <- x3 + rnorm(n, mean = 4, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3),
                   y = c(y1, y2, y3),
                   cluster = rep(1:3, each = n))

# Calculate cluster centers
centers <- aggregate(cbind(x, y) ~ cluster, data, mean)

# Create the scatter plot with cluster centers and regression lines
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  geom_point(data = centers, aes(x = x, y = y), size = 3, shape = 21, fill = "black") +
  geom_smooth(data = data, aes(x = x, y = y, color = factor(cluster)), method = "lm", se = FALSE) +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate four distinct clusters with negative correlations within each cluster
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- -x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- -x2 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 8, sd = 0.5)
y3 <- -x3 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 4
x4 <- rnorm(n, mean = 12, sd = 0.5)
y4 <- -x4 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3, x4),
                   y = c(y1, y2, y3, y4),
                   cluster = rep(1:4, each = n))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, linetype = "dashed") +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate four distinct clusters with negative correlations within each cluster
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- -x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- -x2 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 8, sd = 0.5)
y3 <- -x3 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 4
x4 <- rnorm(n, mean = 12, sd = 0.5)
y4 <- -x4 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3, x4),
                   y = c(y1, y2, y3, y4),
                   cluster = rep(1:4, each = n))

# Compute cluster centers
cluster_centers <- data.frame(cluster = 1:4,
                              x = c(mean(x1), mean(x2), mean(x3), mean(x4)),
                              y = c(mean(y1), mean(y2), mean(y3), mean(y4)))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  geom_smooth(data = cluster_centers, aes(x = x, y = y), method = "lm", se = FALSE, linetype = "dashed") +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Set a seed for reproducibility
set.seed(123)

# Generate four distinct clusters with negative correlations within each cluster
n <- 100 # Number of data points per cluster

# Cluster 1
x1 <- rnorm(n, mean = 0, sd = 0.5)
y1 <- -x1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2
x2 <- rnorm(n, mean = 4, sd = 0.5)
y2 <- -x2 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 3
x3 <- rnorm(n, mean = 8, sd = 0.5)
y3 <- -x3 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 4
x4 <- rnorm(n, mean = 12, sd = 0.5)
y4 <- -x4 + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(x1, x2, x3, x4),
                   y = c(y1, y2, y3, y4),
                   cluster = rep(1:4, each = n))

# Compute cluster centers
cluster_centers <- data.frame(cluster = 1:4,
                              x = c(mean(x1), mean(x2), mean(x3), mean(x4)),
                              y = c(mean(y1), mean(y2), mean(y3), mean(y4)))

# Create the scatter plot
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  geom_smooth(data = cluster_centers, aes(x = x, y = y), method = "lm", se = FALSE, linetype = "dashed") +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate the data
n <- 100 # Number of data points

# Generate x and y variables with a regression coefficient of around 0.75
x <- rnorm(n)
y <- 0.75 * x + rnorm(n, mean = 0, sd = 0.2)

# Create a vector specifying the symbols for each data point
symbols <- rep(c("cross", "plus", "dot"), length.out = n)

# Combine the data
data <- data.frame(x, y, symbols)

# Create the scatter plot
ggplot(data, aes(x = x, y = y, shape = symbols)) +
  geom_point(size = 3) +
  labs(x = "X", y = "Y") +
  scale_shape_manual(values = c("cross" = 3, "plus" = 4, "dot" = 16)) +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate the data
n <- 100 # Number of data points

# Generate x and y variables with a regression coefficient of around 0.75
x <- rnorm(n)
y <- 0.75 * x + rnorm(n, mean = 0, sd = 0.2)

# Create a vector specifying the symbols for each data point
symbols <- rep(c("cross", "plus", "dot"), length.out = n)

# Combine the data
data <- data.frame(x, y, symbols)

# Create the scatter plot
ggplot(data, aes(x = x, y = y, shape = symbols)) +
  geom_point(size = 3) +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +  # Add regression line
  labs(x = "X", y = "Y") +
  scale_shape_manual(values = c("cross" = 3, "plus" = 4, "dot" = 16)) +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate data with different point shapes
n <- 100

# Crosses
cross_x <- rnorm(n, mean = 0, sd = 0.5)
cross_y <- cross_x + rnorm(n, mean = 0, sd = 0.2)

# Plus signs
plus_x <- rnorm(n, mean = 2, sd = 0.5)
plus_y <- plus_x + rnorm(n, mean = 0, sd = 0.2)

# Dots
dot_x <- rnorm(n, mean = 4, sd = 0.5)
dot_y <- dot_x + rnorm(n, mean = 0, sd = 0.2)

# Combine the data
data <- data.frame(x = c(cross_x, plus_x, dot_x),
                   y = c(cross_y, plus_y, dot_y),
                   shape = rep(c("Cross", "Plus", "Dot"), each = n))

# Create the scatter plot with a regression line
ggplot(data, aes(x = x, y = y, shape = shape)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "red") +
  labs(x = "X", y = "Y", shape = "Point Shape") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate the data
n <- 100 # Number of data points

# Generate x and y variables with a regression coefficient of around 0.75
x <- rnorm(n)
y <- 0.75 * x + rnorm(n, mean = 0, sd = 0.2)

# Create a vector specifying the symbols for each data point
symbols <- rep(c("cross", "plus", "dot"), length.out = n)

# Combine the data
data <- data.frame(x, y, symbols)

# Compute group averages
group_averages <- aggregate(data[, c("x", "y")], by = list(data$symbols), FUN = mean)
colnames(group_averages)[1] <- "symbols"

# Create the scatter plot
ggplot(data, aes(x = x, y = y, shape = symbols)) +
  geom_point(size = 3) +
  geom_smooth(method = "lm", se = FALSE, color = "black") +
  labs(x = "X", y = "Y") +
  scale_shape_manual(values = c("cross" = 3, "plus" = 4, "dot" = 16)) +
  geom_text(data = group_averages, aes(label = paste0("Group Avg: ", round(x, 2), ", ", round(y, 2))),
            color = "black", vjust = -0.5, size = 4) +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate the data
n <- 100 # Number of data points

# Generate x and y variables with a regression coefficient of around 0.75
x <- rnorm(n)
y <- 0.75 * x + rnorm(n, mean = 0, sd = 0.2)

# Create a vector specifying the symbols for each data point
symbols <- rep(c("cross", "plus", "dot"), length.out = n)

# Combine the data
data <- data.frame(x, y, symbols)

# Compute group averages
group_averages <- aggregate(data[, c("x", "y")], by = list(data$symbols), FUN = mean)
colnames(group_averages)[1] <- "symbols"

# Create the scatter plot
ggplot(data, aes(x = x, y = y, shape = symbols)) +
  geom_point(size = 3) +
  labs(x = "X", y = "Y") +
  scale_shape_manual(values = c("cross" = 3, "plus" = 4, "dot" = 16)) +
  geom_text(data = group_averages, aes(label = paste0("Group Avg: ", round(x, 2), ", ", round(y, 2))),
            color = "black", vjust = -0.5, size = 4) +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate the data
n <- 100 # Number of data points

# Generate x and y variables with a regression coefficient of around 0.75
x <- rnorm(n)
y <- 0.75 * x + rnorm(n, mean = 0, sd = 0.2)

# Create a vector specifying the symbols for each data point
symbols <- rep(c("cross", "plus", "dot"), length.out = n)

# Combine the data
data <- data.frame(x, y, symbols)

# Compute group averages
group_averages <- aggregate(data[, c("x", "y")], by = list(data$symbols), FUN = mean)
colnames(group_averages)[1] <- "symbols"

# Create the scatter plot
ggplot(data, aes(x = x, y = y, shape = symbols)) +
  geom_point(size = 3) +
  labs(x = "X", y = "Y") +
  scale_shape_manual(values = c("cross" = 3, "plus" = 4, "dot" = 16)) +
  geom_text(data = group_averages, aes(label = paste0("Group Avg: ", round(x, 2), ", ", round(y, 2))),
            color = "red", vjust = -0.5, size = 4) +
  theme_minimal()
# Out:
# plot without title

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate the data
n <- 100 # Number of data points

# Generate x and y variables with a regression coefficient of around 0.75
x <- rnorm(n)
y <- 0.50 * x + rnorm(n, mean = 0, sd = 0.2)

# Create a vector specifying the symbols for each data point
symbols <- rep(c("cross", "plus", "dot"), length.out = n)

# Combine the data
data <- data.frame(x, y, symbols)

# Compute group averages
group_averages <- aggregate(data[, c("x", "y")], by = list(data$symbols), FUN = mean)
colnames(group_averages)[1] <- "symbols"

# Create the scatter plot
ggplot(data, aes(x = x, y = y, shape = symbols)) +
  geom_point(size = 3) +
  labs(x = "X", y = "Y") +
  scale_shape_manual(values = c("cross" = 3, "plus" = 4, "dot" = 16)) +
  geom_point(data = group_averages, aes(x = x, y = y), color = "red", size = 5, shape = 19) +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ---

# %%
# Load the required library
library(ggplot2)

# Set a seed for reproducibility
set.seed(123)

# Generate four smaller distinct clusters with rotated positions
n <- 100 # Number of data points per cluster

# Cluster 1 (Rotated)
y1 <- rnorm(n, mean = 0, sd = 0.5)
x1 <- -y1 + rnorm(n, mean = 0, sd = 0.2)

# Cluster 2 (Rotated)
y2 <- rnorm(n, mean = 4, sd = 0.5)
x2 <- y2 + rnorm(n, mean = 0, sd = 0.2)

cluster_center2 <- data.frame(x = mean(x2), y = mean(y2))

rotated_x2 <- cluster_center2$x + (y2 - cluster_center2$y)
rotated_y2 <- cluster_center2$y - (x2 - cluster_center2$x)

# Cluster 3 (Rotated)
y3 <- rnorm(n, mean = 8, sd = 0.5)
x3 <- y3 + rnorm(n, mean = 0, sd = 0.2)

cluster_center3 <- data.frame(x = mean(x3), y = mean(y3))

rotated_x3 <- cluster_center3$x + (y3 - cluster_center3$y)
rotated_y3 <- cluster_center3$y - (x3 - cluster_center3$x)

# Cluster 4 (Rotated)
y4 <- rnorm(n, mean = 12, sd = 0.5)
x4 <- y4 + rnorm(n, mean = 0, sd = 0.2)

cluster_center4 <- data.frame(x = mean(x4), y = mean(y4))

rotated_x4 <- cluster_center4$x + (y4 - cluster_center4$y)
rotated_y4 <- cluster_center4$y - (x4 - cluster_center4$x)

# Combine the data
data <- data.frame(x = c(x1, rotated_x2, rotated_x3, rotated_x4),
                   y = c(y1, rotated_y2, rotated_y3, rotated_y4),
                   cluster = rep(1:4, each = n))

# Create the scatter plot with cluster centers
ggplot(data, aes(x = x, y = y, color = factor(cluster))) +
  geom_point() +
  geom_point(data = cluster_center2, aes(x = x, y = y), shape = 19, size = 4, color = "red", fill = "red") +
  geom_point(data = cluster_center3, aes(x = x, y = y), shape = 19, size = 4, color = "blue", fill = "blue") +
  geom_point(data = cluster_center4, aes(x = x, y = y), shape = 19, size = 4, color = "green", fill = "green") +
  labs(x = "X", y = "Y", color = "Cluster") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ---

# %%
# Sample data for clusters forming an approximate straight line
set.seed(123) # For reproducibility
num_points_per_cluster <- 50

cluster1 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 2, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 3, sd = 0.5)
)

cluster2 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 2.5, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 2.5, sd = 0.5)
)

cluster3 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 3, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 2, sd = 0.5)
)

# Sample data for the fourth cluster on the right
num_points_cluster4 <- 30

cluster4 <- data.frame(
  x = rnorm(num_points_cluster4, mean = 8, sd = 1),
  y = rnorm(num_points_cluster4, mean = 5, sd = 0.8)
)

# Combining all clusters
all_clusters <- rbind(cluster1, cluster2, cluster3, cluster4)

# Plotting the clusters
ggplot(all_clusters, aes(x = x, y = y)) +
  geom_point(size = 3, shape = 16) +
  theme_minimal() +
  labs(title = "Clusters of Points",
       x = "X-axis",
       y = "Y-axis")
# Out:
# plot without title

# %% [markdown]
# ---

# %%
# Sample data for three clusters forming an approximate straight line on the left
set.seed(123)

num_points_per_cluster <- 50

cluster1 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 5, sd = 0.6),
  y = rnorm(num_points_per_cluster, mean = 6, sd = 0.5)
)

cluster2 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 4, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 4, sd = 0.5)
)

cluster3 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 4, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 2, sd = 0.5)
)

# Sample data for the fourth cluster on the right
num_points_cluster4 <- 50

cluster4 <- data.frame(
  x = rnorm(num_points_cluster4, mean = 8, sd = 0.5),
  y = rnorm(num_points_cluster4, mean = 5, sd = 0.6)
)

# Combining all clusters
all_clusters <- rbind(cluster1, cluster2, cluster3, cluster4)

# Plotting the clusters
ggplot(all_clusters, aes(x = x, y = y)) +
  geom_point(size = 3, shape = 16) +
  theme_minimal() +
  labs(title = "Clusters of Points",
       x = "X-axis",
       y = "Y-axis")
# Out:
# plot without title

# %%
library(ggplot2)
library(dplyr)

# Sample data for three clusters forming an approximate straight line on the left
set.seed(123)

num_points_per_cluster <- 50

cluster1 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 5, sd = 0.6),
  y = rnorm(num_points_per_cluster, mean = 6, sd = 0.5),
  cluster = "Cluster 1"
)

cluster2 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 4, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 4, sd = 0.5),
  cluster = "Cluster 2"
)

cluster3 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 4, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 2, sd = 0.5),
  cluster = "Cluster 3"
)

# Sample data for the fourth cluster on the right
num_points_cluster4 <- 50

cluster4 <- data.frame(
  x = rnorm(num_points_cluster4, mean = 8, sd = 0.5),
  y = rnorm(num_points_cluster4, mean = 5, sd = 0.6),
  cluster = "Cluster 4"
)

# Combining all clusters
all_clusters <- rbind(cluster1, cluster2, cluster3, cluster4)

# Calculate cluster centers
cluster_centers <- all_clusters %>%
  group_by(cluster) %>%
  summarize(center_x = mean(x), center_y = mean(y))

# Plotting the clusters and cluster centers
ggplot(all_clusters, aes(x = x, y = y, color = cluster)) +
  geom_point(size = 3, shape = 16) +
  geom_point(data = cluster_centers, aes(x = center_x, y = center_y), size = 5, shape = 3, color = "black") +
  theme_minimal() +
  labs(title = "Clusters of Points and Cluster Centers",
       x = "X-axis",
       y = "Y-axis")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# plot without title

# %%
library(ggplot2)
library(dplyr)

# Sample data for three clusters forming an approximate straight line on the left
set.seed(123)

num_points_per_cluster <- 100

cluster1 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 11, sd = 0.6),
  y = rnorm(num_points_per_cluster, mean = 14, sd = 0.5),
  cluster = "Cluster 1"
)

cluster2 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 9, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 10, sd = 0.5),
  cluster = "Cluster 2"
)

cluster3 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 9, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 7, sd = 0.5),
  cluster = "Cluster 3"
)

# Sample data for the fourth cluster on the right
num_points_cluster4 <- 50

cluster4 <- data.frame(
  x = rnorm(num_points_cluster4, mean = 15, sd = 0.5),
  y = rnorm(num_points_cluster4, mean = 10, sd = 0.6),
  cluster = "Cluster 4"
)

# Combining all clusters
all_clusters <- rbind(cluster1, cluster2, cluster3, cluster4)

# Calculate cluster centers
cluster_centers <- all_clusters %>%
  group_by(cluster) %>%
  summarize(center_x = mean(x), center_y = mean(y))

# Create a data frame for cluster centers with unique shapes for each cluster
shapes_df <- data.frame(
  cluster = unique(all_clusters$cluster),
  shape = seq(16, 19, length.out = length(unique(all_clusters$cluster)))
)

# Merge cluster centers with shapes
cluster_centers <- merge(cluster_centers, shapes_df, by = "cluster")

# Plotting the clusters and cluster centers
ggplot(all_clusters, aes(x = x, y = y, color = cluster)) +
  geom_point(size = 3, shape = 16) +
  geom_point(data = cluster_centers, aes(x = center_x, y = center_y, color = cluster, shape = shape), size = 5) +
  scale_shape_identity() +
  theme_minimal() +
  labs(title = "Clusters of Points and Cluster Centers",
       x = "X-axis",
       y = "Y-axis")
# Out:
# plot without title

# %%
library(ggplot2)
library(dplyr)

# Sample data for three clusters forming an approximate straight line on the left
set.seed(123)

num_points_per_cluster <- 100

cluster1 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 11, sd = 0.6),
  y = rnorm(num_points_per_cluster, mean = 14, sd = 0.5),
  cluster = "Cluster 1"
)

cluster2 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 9, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 10, sd = 0.5),
  cluster = "Cluster 2"
)

cluster3 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 9, sd = 0.3),
  y = rnorm(num_points_per_cluster, mean = 7, sd = 0.5),
  cluster = "Cluster 3"
)

# Sample data for the fourth cluster on the right
num_points_cluster4 <- 50

cluster4 <- data.frame(
  x = rnorm(num_points_cluster4, mean = 15, sd = 0.5),
  y = rnorm(num_points_cluster4, mean = 10, sd = 0.6),
  cluster = "Cluster 4"
)

# Combining all clusters
all_clusters <- rbind(cluster1, cluster2, cluster3, cluster4)

# Calculate cluster centers
cluster_centers <- all_clusters %>%
  group_by(cluster) %>%
  summarize(center_x = mean(x), center_y = mean(y))

# Create a data frame for cluster centers with unique shapes for each cluster
shapes_df <- data.frame(
  cluster = unique(all_clusters$cluster),
  shape = seq(16, 19, length.out = length(unique(all_clusters$cluster)))
)

# Merge cluster centers with shapes
cluster_centers <- merge(cluster_centers, shapes_df, by = "cluster")

# Plotting the clusters and cluster centers with regression lines
ggplot(all_clusters, aes(x = x, y = y, color = cluster)) +
  geom_point(size = 2, shape = 16) +  # Adjust the size of the points here (size = 2)
  geom_point(data = cluster_centers, aes(x = center_x, y = center_y, color = cluster, shape = shape), size = 3) +
  geom_smooth(method = "lm", se = FALSE, aes(group = cluster, color = cluster)) +  # Add regression lines with cluster-specific color
  scale_shape_identity() +
  theme_minimal() +
  labs(title = "Clusters of Points and Cluster Centers with Regression Lines",
       x = "X-axis",
       y = "Y-axis")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
library(ggplot2)
library(dplyr)

# Sample data for three clusters forming an approximate straight line on the left
set.seed(123)

options(repr.plot.width = 15, repr.plot.height = 15)

num_points_per_cluster <- 250

cluster1 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 30, sd = 2.6),
  y = rnorm(num_points_per_cluster, mean = 30, sd = 2.5),
  cluster = "Cluster 1"
)

cluster2 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 21, sd = 2.3),
  y = rnorm(num_points_per_cluster, mean = 25, sd = 2.5),
  cluster = "Cluster 2"
)

cluster3 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 20, sd = 2.3),
  y = rnorm(num_points_per_cluster, mean = 10, sd = 2.5),
  cluster = "Cluster 3"
)

# Sample data for the fourth cluster on the right
num_points_cluster4 <- 250

cluster4 <- data.frame(
  x = rnorm(num_points_cluster4, mean = 40, sd = 2.5),
  y = rnorm(num_points_cluster4, mean = 20, sd = 2.6),
  cluster = "Cluster 4"
)

# Combining all clusters
all_clusters <- rbind(cluster1, cluster2, cluster3, cluster4)

# Calculate cluster centers
cluster_centers <- all_clusters %>%
  group_by(cluster) %>%
  summarize(center_x = mean(x), center_y = mean(y))

# Create a data frame for cluster centers with unique shapes for each cluster
shapes_df <- data.frame(
  cluster = unique(all_clusters$cluster),
  shape = seq(16, 19, length.out = length(unique(all_clusters$cluster)))
)

# Merge cluster centers with shapes
cluster_centers <- merge(cluster_centers, shapes_df, by = "cluster")

# Plotting the clusters and cluster centers with regression lines
ggplot(all_clusters, aes(x = x, y = y, color = cluster)) +
  geom_point(size = 2, shape = 16) +  # Adjust the size of the points here (size = 2)
  geom_point(data = cluster_centers, aes(x = center_x, y = center_y), size = 3, color = "red") +  # Make the cluster centers bright red
  geom_smooth(method = "lm", se = FALSE, aes(group = cluster, color = cluster)) +  # Add regression lines with cluster-specific color
  scale_shape_identity() +
  theme_minimal() +
  labs(title = "Clusters of Points and Cluster Centers with Regression Lines",
       x = "X-axis",
       y = "Y-axis")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
library(ggplot2)
library(dplyr)

# Sample data for three clusters forming an approximate straight line on the left
set.seed(123)

options(repr.plot.width = 15, repr.plot.height = 15)

num_points_per_cluster <- 250

cluster1 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 30, sd = 2.6),
  y = rnorm(num_points_per_cluster, mean = 30, sd = 2.5),
  cluster = "Cluster 1"
)

cluster2 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 21, sd = 2.3),
  y = rnorm(num_points_per_cluster, mean = 25, sd = 2.5),
  cluster = "Cluster 2"
)

cluster3 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 20, sd = 2.3),
  y = rnorm(num_points_per_cluster, mean = 10, sd = 2.5),
  cluster = "Cluster 3"
)

# Sample data for the fourth cluster on the right
num_points_cluster4 <- 250

cluster4 <- data.frame(
  x = rnorm(num_points_cluster4, mean = 40, sd = 2.5),
  y = rnorm(num_points_cluster4, mean = 20, sd = 2.6),
  cluster = "Cluster 4"
)

# Combining all clusters
all_clusters <- rbind(cluster1, cluster2, cluster3, cluster4)

# Calculate cluster centers
cluster_centers <- all_clusters %>%
  group_by(cluster) %>%
  summarize(center_x = mean(x), center_y = mean(y))

# Create a data frame for cluster centers with unique shapes for each cluster
shapes_df <- data.frame(
  cluster = unique(all_clusters$cluster),
  shape = seq(16, 19, length.out = length(unique(all_clusters$cluster)))
)

# Merge cluster centers with shapes
cluster_centers <- merge(cluster_centers, shapes_df, by = "cluster")

# Plotting the clusters and cluster centers with regression lines
ggplot(all_clusters, aes(x = x, y = y, color = cluster)) +
  geom_point(size = 2, shape = 16) +  # Adjust the size of the points here (size = 2)
  geom_point(data = cluster_centers, aes(x = center_x, y = center_y), size = 8, color = "red") +  # Make the cluster centers bright red
  geom_smooth(method = "lm", se = FALSE, aes(group = cluster, color = cluster)) +  # Add regression lines with cluster-specific color
  geom_smooth(method = "lm", se = FALSE, aes(color = "red"), size = 1) +  # Add overall regression line
  scale_shape_identity() +
  theme_minimal() +
  labs(title = "Clusters of Points and Cluster Centers with Regression Lines",
       x = "X-axis",
       y = "Y-axis")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
library(ggplot2)
library(dplyr)

# Sample data for three clusters forming an approximate straight line on the left
set.seed(123)

options(repr.plot.width = 15, repr.plot.height = 15)

num_points_per_cluster <- 250

cluster1 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 30, sd = 2.6),
  y = rnorm(num_points_per_cluster, mean = 30, sd = 2.5),
  cluster = "Cluster 1"
)

cluster2 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 21, sd = 2.3),
  y = rnorm(num_points_per_cluster, mean = 15, sd = 2.5),
  cluster = "Cluster 2"
)

cluster3 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 20, sd = 2.3),
  y = rnorm(num_points_per_cluster, mean = 30 - 2 * rnorm(num_points_per_cluster, mean = 20, sd = 2.3), sd = 2.5),
  cluster = "Cluster 3"
)

# Sample data for the fourth cluster on the right
num_points_cluster4 <- 250

cluster4 <- data.frame(
  x = rnorm(num_points_cluster4, mean = 40, sd = 2.5),
  y = rnorm(num_points_cluster4, mean = 20, sd = 2.6),
  cluster = "Cluster 4"
)

# Combining all clusters
all_clusters <- rbind(cluster1, cluster2, cluster3, cluster4)

# Calculate cluster centers
cluster_centers <- all_clusters %>%
  group_by(cluster) %>%
  summarize(center_x = mean(x), center_y = mean(y))

# Create a data frame for cluster centers with unique shapes for each cluster
shapes_df <- data.frame(
  cluster = unique(all_clusters$cluster),
  shape = seq(16, 19, length.out = length(unique(all_clusters$cluster)))
)

# Merge cluster centers with shapes
cluster_centers <- merge(cluster_centers, shapes_df, by = "cluster")

# Plotting the clusters and cluster centers with regression lines
ggplot(all_clusters, aes(x = x, y = y, color = cluster)) +
  geom_point(size = 2, shape = 16) +
  geom_point(data = cluster_centers, aes(x = center_x, y = center_y), size = 8, color = "red") +
  geom_smooth(method = "lm", se = FALSE, aes(group = cluster, color = cluster)) +
  geom_smooth(data = all_clusters, method = "lm", se = FALSE, aes(color = "red"), size = 1) +
  scale_shape_identity() +
  theme_minimal() +
  labs(title = "Clusters of Points and Cluster Centers with Regression Lines",
       x = "X-axis",
       y = "Y-axis")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
library(ggplot2)
library(dplyr)

# Sample data for three clusters forming an approximate straight line on the left
set.seed(123)

options(repr.plot.width = 15, repr.plot.height = 15)

num_points_per_cluster <- 250

cluster1 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 30, sd = 3),
  y = rnorm(num_points_per_cluster, mean = 30- 2 * rnorm(num_points_per_cluster, mean = 15, sd = 2.3), sd = 1.5),
  cluster = "Cluster 1"
)

cluster2 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 21, sd = 2.3),
  y = rnorm(num_points_per_cluster, mean = 15, sd = 2.5),
  cluster = "Cluster 2"
)

cluster3 <- data.frame(
  x = rnorm(num_points_per_cluster, mean = 20, sd = 3),
  y = rnorm(num_points_per_cluster, mean = 30 - 2 * rnorm(num_points_per_cluster, mean = 20, sd = 2.3), sd = 1),
  cluster = "Cluster 3"
)
#cluster3$y <- -cluster3$y

# Sample data for the fourth cluster on the right
num_points_cluster4 <- 250

cluster4 <- data.frame(
  x = rnorm(num_points_cluster4, mean = 40, sd = 2.5),
  y = rnorm(num_points_cluster4, mean = 20, sd = 2.6),
  cluster = "Cluster 4"
)

# Combining all clusters
all_clusters <- rbind(cluster1, cluster2, cluster3, cluster4)

# Calculate cluster centers
cluster_centers <- all_clusters %>%
  group_by(cluster) %>%
  summarize(center_x = mean(x), center_y = mean(y))

# Create a data frame for cluster centers with unique shapes for each cluster
shapes_df <- data.frame(
  cluster = unique(all_clusters$cluster),
  shape = seq(16, 19, length.out = length(unique(all_clusters$cluster)))
)

# Merge cluster centers with shapes
cluster_centers <- merge(cluster_centers, shapes_df, by = "cluster")

# Calculate overall R-squared value for the overall regression line
overall_model <- lm(y ~ x, data = all_clusters)
overall_r_squared <- summary(overall_model)$r.squared

# Plotting the clusters and cluster centers with regression lines and R-squared value
ggplot(all_clusters, aes(x = x, y = y, color = cluster)) +
  geom_point(size = 2, shape = 16) +
  geom_point(data = cluster_centers, aes(x = center_x, y = center_y), size = 8, color = "red") +
  geom_smooth(method = "lm", se = FALSE, aes(group = cluster, color = cluster)) +
  geom_smooth(data = all_clusters, method = "lm", se = FALSE, aes(color = "Overall Regression"), size = 1) +
  #geom_text(aes(x = 35, y = 10, label = paste0("Overall R^2 = ", round(overall_r_squared, 3))),
            #color = "black", size = 5, hjust = 0) +
  scale_shape_identity() +
  theme_minimal() +
  labs(title = "Clusters of Points and Cluster Centers with Regression Lines",
       x = "X-axis",
       y = "Y-axis")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
