# %% [markdown]
# Add Duration, PG/G/R Rating, IMDB Audience Score
#
# https://www.imdb.com/search/title/?year=2000&title_type=feature&

# %% [markdown]
# Film years.
# https://www.imdb.com/search/title/?year=1927&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=1929&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=1930&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=1931&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=1933&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=1934&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=1935&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=1936&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1937&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1938&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1939&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1940&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1941&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1942&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1943&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1944&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1945&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1946&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1947&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1948&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1949&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1950&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1951&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1952&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1953&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=1954&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1955&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1956&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1957&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1958&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1959&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1960&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1961&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1962&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1963&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1964&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1965&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1966&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1967&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1968&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1969&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1970&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1971&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1972&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1973&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1974&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1975&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1976&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1977&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1978&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1979&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=1980&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1981&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1982&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1983&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1984&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1985&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1986&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1987&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1988&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1989&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1990&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1991&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1992&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1993&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1994&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1995&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1996&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1997&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1998&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=1999&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2000&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2001&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2002&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2003&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2004&amp;title_type=feature&amp;
#
# https://www.imdb.com/search/title/?year=2005&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2006&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2007&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2008&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2009&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2010&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2011&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2012&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2013&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2014&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2015&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2016&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2017&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2018&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2019&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2020&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2021&amp;title_type=feature&amp;
# https://www.imdb.com/search/title/?year=2022&amp;title_type=feature&amp;

# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup as bs
from pprint import pprint
import numpy as np
from webdriver_manager.chrome import ChromeDriverManager

# %%
wd = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# C:\Users\redoc\AppData\Local\Temp\ipykernel_5248\3832095755.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome(ChromeDriverManager().install())

# %%
url_link = "https://www.imdb.com/search/title/?year=1927&title_type=feature&"

# %%
wd.get(url_link)

# %% [markdown]
# Years: 1927 to 2021

# %% [markdown]
# I will only scrape from 1980. Or I will need a day to run the program.

# %%
years_ = np.arange(1980,2022,1)
years_
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])

# %%
url_links = []

for year_ in years_:
    url_ = "https://www.imdb.com/search/title/?year="+str(year_)+"&title_type=feature&"
    url_links.append(url_)

# %%
url_links
# Out:
# ['https://www.imdb.com/search/title/?year=1980&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1981&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1982&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1983&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1984&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1985&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1986&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1987&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1988&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1989&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1990&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1991&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1992&title_type=feature&',
#  'https://www.imdb.com/search/title/?year=1993&title_type=feature&',
# ...

# %% [markdown]
# Every year has a long list of movies. Let's see how each list URL looks like

# %% [markdown]
# ## Year 2020
#
# https://www.imdb.com/search/title/?title_type=feature&year=2020-01-01,2020-12-31&ref_=adv_prv
#
# https://www.imdb.com/search/title/?title_type=feature&year=2020-01-01,2020-12-31&start=51&ref_=adv_nxt
#
# https://www.imdb.com/search/title/?title_type=feature&year=2020-01-01,2020-12-31&start=101&ref_=adv_nxt
#
# https://www.imdb.com/search/title/?title_type=feature&year=2020-01-01,2020-12-31&start=151&ref_=adv_nxt
#
# ## Year 2018
#
# https://www.imdb.com/search/title/?title_type=feature&year=2018-01-01,2018-12-31&ref_=adv_prv
#
# https://www.imdb.com/search/title/?title_type=feature&year=2018-01-01,2018-12-31&start=51&ref_=adv_nxt
#
# https://www.imdb.com/search/title/?title_type=feature&year=2018-01-01,2018-12-31&start=101&ref_=adv_nxt
#
# https://www.imdb.com/search/title/?title_type=feature&year=2018-01-01,2018-12-31&start=151&ref_=adv_nxt

# %% [markdown]
# I need to create a new list of URLs. On average every year there are 13000 movies. So I will need to scrape this much

# %%
page_num = np.arange(51,13051,50)
page_num
# Out:
# array([   51,   101,   151,   201,   251,   301,   351,   401,   451,
#          501,   551,   601,   651,   701,   751,   801,   851,   901,
#          951,  1001,  1051,  1101,  1151,  1201,  1251,  1301,  1351,
#         1401,  1451,  1501,  1551,  1601,  1651,  1701,  1751,  1801,
#         1851,  1901,  1951,  2001,  2051,  2101,  2151,  2201,  2251,
#         2301,  2351,  2401,  2451,  2501,  2551,  2601,  2651,  2701,
#         2751,  2801,  2851,  2901,  2951,  3001,  3051,  3101,  3151,
#         3201,  3251,  3301,  3351,  3401,  3451,  3501,  3551,  3601,
#         3651,  3701,  3751,  3801,  3851,  3901,  3951,  4001,  4051,
#         4101,  4151,  4201,  4251,  4301,  4351,  4401,  4451,  4501,
#         4551,  4601,  4651,  4701,  4751,  4801,  4851,  4901,  4951,
#         5001,  5051,  5101,  5151,  5201,  5251,  5301,  5351,  5401,
#         5451,  5501,  5551,  5601,  5651,  5701,  5751,  5801,  5851,
# ...

# %%
url_links = []

for year_ in years_:
    for page_ in page_num:
        url_ = "https://www.imdb.com/search/title/?title_type=feature&year="+str(year_)+"-01-01,"+str(year_)+"-12-31&start="+str(page_)+"&ref_=adv_nxt"
        url_links.append(url_)

# %%
url_links
# Out:
# ['https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=51&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=101&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=151&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=201&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=251&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=301&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=351&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=401&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=451&ref_=adv_nxt',
# ...

# %% [markdown]
# Add first 50 movies from each year

# %%
for year_ in years_:
    url_ = "https://www.imdb.com/search/title/?title_type=feature&year="+str(year_)+"-01-01,"+str(year_)+"-12-31&ref_=adv_prv"
    url_links.append(url_)

# %%
url_links
# Out:
# ['https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=51&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=101&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=151&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=201&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=251&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=301&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=351&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=401&ref_=adv_nxt',
#  'https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=451&ref_=adv_nxt',
# ...

# %% [markdown]
# ---

# %% [markdown]
# # XPaths
#
# ## Title
#
# //*[@id="main"]/div/div[3]/div/div[3]/div[3]/h3/a
#
# //*[@id="main"]/div/div[3]/div/div[5]/div[3]/h3/a
#
# //*[@id="main"]/div/div[3]/div/div[9]/div[3]/h3/a
#
# ## Duration
#
# //*[@id="main"]/div/div[3]/div/div[8]/div[3]/p[1]/span[3]
#
# //*[@id="main"]/div/div[3]/div/div[17]/div[3]/p[1]/span[3]
#
# //*[@id="main"]/div/div[3]/div/div[20]/div[3]/p[1]/span[3]
#
# ## Age Appropriate Rating
#
# //*[@id="main"]/div/div[3]/div/div[19]/div[3]/p[1]/span[1]
#
# //*[@id="main"]/div/div[3]/div/div[23]/div[3]/p[1]/span[1]
#
# //*[@id="main"]/div/div[3]/div/div[29]/div[3]/p[1]/span[1]
#
# ## IMDB Score(Star)
#
# //*[@id="main"]/div/div[3]/div/div[33]/div[3]/div/div[1]/strong
#
# //*[@id="main"]/div/div[3]/div/div[37]/div[3]/div/div[1]/strong
#
# //*[@id="main"]/div/div[3]/div/div[42]/div[3]/div/div[1]/strong
#
# ## Metascore
#
# //*[@id="main"]/div/div[3]/div/div[49]/div[3]/div/div[3]/span
#
# //*[@id="main"]/div/div[3]/div/div[50]/div[3]/div/div[3]/span
#
# //*[@id="main"]/div/div[3]/div/div[33]/div[3]/div/div[3]/span
#
# ## Genre
#
# //*[@id="main"]/div/div[3]/div/div[38]/div[3]/p[1]/span[5]
#
# //*[@id="main"]/div/div[3]/div/div[24]/div[3]/p[1]/span[5]
#
# //*[@id="main"]/div/div[3]/div/div[12]/div[3]/p[1]/span[5]
#
# ## Votes
#
# //*[@id="main"]/div/div[3]/div/div[2]/div[3]/p[4]/span[2]
#
# //*[@id="main"]/div/div[3]/div/div[12]/div[3]/p[4]/span[2]
#
# //*[@id="main"]/div/div[3]/div/div[27]/div[3]/p[4]/span[2]

# %% [markdown]
# ---

# %% [markdown]
# Base XPath
#
# //*[@id="main"]/div/div[3]/div/div[ROW INDEX]

# %% [markdown]
# ---

# %%
rows_ = np.arange(1,50,1)

# %% [markdown]
# //*[@id="main"]/div/div[3]/div/div[1]/div[3]/h3/a
#
# //*[@id="main"]/div/div[3]/div/div[50]/div[3]/h3/a

# %%
wd = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# C:\Users\redoc\AppData\Local\Temp\ipykernel_5248\3832095755.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome(ChromeDriverManager().install())

# %%
# page_num = np.arange(51,13051,50)

# %% [markdown]
# Re code it to set the scrape limit to this parameter
#
# //*[@id="main"]/div/div[1]/div[2]/span[1]

# %%
wd.get("https://www.imdb.com/search/title/?title_type=feature&year=1980-01-01,1980-12-31&start=51&ref_=adv_nxt")

# %%
wd.find_element("xpath","//*[@id='main']/div/div[1]/div[2]/span[1]").text
# Out:
# '51-100 of 3,382 titles.'

# %%
movie_list = []

for url_ in url_links:
    try:
        wd.get(url_)

        for row_ in rows_:
            movie = {}   

            try:
                movie['Title'] = wd.find_element("xpath","//*[@id='main']/div/div[3]/div/div["+str(row_)+"]"+"/div[3]/h3/a").text     
                movie['Duration'] = wd.find_element("xpath","//*[@id='main']/div/div[3]/div/div["+str(row_)+"]"+"/div[3]/p[1]/span[3]").text
                movie['Age Appropriate Rating'] = wd.find_element("xpath","//*[@id='main']/div/div[3]/div/div["+str(row_)+"]"+"/div[3]/p[1]/span[1]").text
                movie['IMDB Score(Star)'] = wd.find_element("xpath","//*[@id='main']/div/div[3]/div/div["+str(row_)+"]"+"/div[3]/div/div[1]/strong").text
                movie['Metascore'] = wd.find_element("xpath","//*[@id='main']/div/div[3]/div/div["+str(row_)+"]"+"/div[3]/div/div[3]/span").text
                movie['Genre'] = wd.find_element("xpath","//*[@id='main']/div/div[3]/div/div["+str(row_)+"]"+"/div[3]/p[1]/span[5]").text
                movie['Votes'] = wd.find_element("xpath","//*[@id='main']/div/div[3]/div/div["+str(row_)+"]"+"/div[3]/p[4]/span[2]").text
            except:
                pass
            movie_list.append(movie)
    except:   
        pass

# %%
imdb_movies_df = pd.DataFrame(movie_list)

imdb_movies_df.dropna(axis = 0, how = 'all', inplace = True) # drop rows with all NaN values

imdb_movies_df.head()

imdb_movies_df.to_csv('IMDB_Movie_Scrape_Final.csv')

# %% [markdown]
# ---

# %% [markdown]
# # REDO

# %% [markdown]
# # Scrape ALL movies from 2022 list to include
#
# **Numerical Data** - budget, domestic gross, us gross, opening weekend gross, voters, duration
#
# **Categorical** - parental rating, mpaa rating, genre, imdb rating, metascore

# %%
from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup as bs
from pprint import pprint
import numpy as np
from webdriver_manager.chrome import ChromeDriverManager

# %%
wd = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# C:\Users\redoc\AppData\Local\Temp\ipykernel_5248\3832095755.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome(ChromeDriverManager().install())

# %% [markdown]
# https://www.imdb.com/title/tt1488589/?ref_=adv_li_tt
#
# https://www.imdb.com/title/tt1630029/?ref_=adv_li_tt
#
# https://www.imdb.com/title/tt9764362/?ref_=adv_li_tt
#
# https://www.imdb.com/title/tt14714980/?ref_=adv_li_tt
#
# https://www.imdb.com/title/tt7947604/?ref_=adv_li_tt
#
# Each movie has a 7-8 digit serial number

# %%
serial_number = np.arange(1000000,10000000,1)

# %%
url_list = []

for index_ in serial_number:
    url_ = "https://www.imdb.com/title/tt"+str(index_)+"/?ref_=adv_li_tt"
    url_list.append(url_)

# %%
print(len(url_list))
# Out:
# 9000000

# %% [markdown]
# **Numerical Data** - budget, domestic gross, us gross, opening weekend gross, voters, duration
#
# **Categorical** - parental rating, mpaa rating, genre, imdb rating, metascore

# %% [markdown]
# # XPaths
#
# ## Title
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/h1
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/h1
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/h1
#
# ## Year
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[1]/span
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[1]/span
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[1]/span
#
# ## Duration
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[3]
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[3]
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[3]
#
# ## Parental Rating
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[2]/span
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[2]/span
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div[1]/div/ul/li[2]/span
#
# ## IMDB Rating (Star and out of 10)
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[2]/div/div[1]/a/div/div/div[2]/div[1]/span[1]
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[2]/div/div[1]/a/div/div/div[2]/div[1]/span[1]
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[2]/div/div[1]/a/div/div/div[2]/div[1]/span[1]
#
# ## Voters
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[2]/div/div[1]/a/div/div/div[2]/div[3]
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[2]/div/div[1]/a/div/div/div[2]/div[3]
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[1]/div[2]/div/div[1]/a/div/div/div[2]/div[3]
#
# ## Metascore
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[2]/ul/li[3]/a/span/span[1]/span
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[2]/ul/li[3]/a/span/span[1]/span
#
# //*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div[2]/div[2]/ul/li[3]/a/span/span[1]/span
#
# ## First Genre
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[5]/div[2]/ul[2]/li[1]/div/ul/li[1]/a
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[5]/div[2]/ul[2]/li[2]/div/ul/li[1]/a
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[6]/div[2]/ul[2]/li[1]/div/ul/li[1]/a
#
# **EVERYTHING CONSISTENT UP TILL HERE**
#
# ## All Genres
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[5]/div[2]/ul[2]/li[2]/div
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[5]/div[2]/ul[2]/li[1]/div
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[6]/div[2]/ul[2]/li[1]/div
#
# ## Release Date
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[10]/div[2]/ul/li[1]/div/ul/li/a
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[10]/div[2]/ul/li[1]/div/ul/li/a
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[1]/div/ul/li/a
#
# ## Language
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[10]/div[2]/ul/li[4]/div/ul/li/a
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[10]/div[2]/ul/li[4]/div/ul/li/a
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[4]/div/ul/li/a
#
# ## Budget (Not every page has budget info)
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[14]/div[2]/ul/li[1]/div/ul/li/label
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[1]/div/ul/li/label
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[1]/div/ul/li/label
#
# ## Gross US Canada
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[14]/div[2]/ul/li[2]/div/ul/li/label
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[2]/div/ul/li/label
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[2]/div/ul/li/label
#
# ## Opening Weekend US Canada Gross
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[14]/div[2]/ul/li[3]/div/ul/li[1]/label
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[3]/div/ul/li[1]/label
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[3]/div/ul/li[1]/label
#
# ## Worldwide Gross
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[14]/div[2]/ul/li[4]/div/ul/li/label
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[4]/div/ul/li/label
#
# //*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[11]/div[2]/ul/li[4]/div/ul/li/label

# %%
wd.get("https://www.imdb.com/title/tt4614584/?ref_=adv_li_tt")

# %%
wd.find_element("xpath","//*[@id='__next']/main/div/section[1]/div/section/div/div[1]/section[5]/div[2]/ul[2]/li[1]/div/ul/li[1]/a").text
# Out:
# 'Drama'

# %%
wd.find_element("xpath","//*[@id='__next']/main/div/section[1]/div/section/div/div[1]/section[5]/div[2]/ul[2]/li[1]").text
# Out:
# 'Genres\nDramaMusicRomance'

# %%
wd.find_element("xpath","//*[@id='__next']/main/div/section[1]/div/section/div/div[1]/section[5]/div[2]/ul[2]/li[1]/div").text
# Out:
# 'DramaMusicRomance'

# %% [markdown]
# Filter those pages without budget data using if else
